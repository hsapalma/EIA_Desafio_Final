# %%
# %pip install scikt-learn
# %pip install matplotlib
# %pip install pandas
# %pip install tensorflow
# %pip install tpot
# %pip install seaborn

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from sklearn.neural_network import MLPClassifier
from tpot import TPOTClassifier
import matplotlib.pyplot as plt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement scikt-learn (from versions: none)
# ERROR: No matching distribution found for scikt-learn
# Requirement already satisfied: matplotlib in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (5.29.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.69.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.7.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.19.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tpot in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tpot) (2.0.2)
# Requirement already satisfied: scipy>=1.3.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tpot) (1.15.0)
# Requirement already satisfied: scikit-learn>=1.4.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tpot) (1.6.0)
# Requirement already satisfied: deap>=1.2 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tpot) (1.4.2)
# Requirement already satisfied: update-checker>=0.16 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tpot) (0.18.0)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tpot) (4.67.1)
# Requirement already satisfied: stopit>=1.1.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tpot) (1.1.2)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tpot) (2.2.3)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tpot) (1.4.2)
# Requirement already satisfied: xgboost>=1.1.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tpot) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from pandas>=0.24.2->tpot) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from pandas>=0.24.2->tpot) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from pandas>=0.24.2->tpot) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from scikit-learn>=1.4.1->tpot) (3.5.0)
# Requirement already satisfied: colorama in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from tqdm>=4.36.1->tpot) (0.4.6)
# Requirement already satisfied: requests>=2.3.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from update-checker>=0.16->tpot) (2.32.3)
# Requirement already satisfied: six>=1.5 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.24.2->tpot) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2024.12.14)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install ucimlrepo

from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
adult = fetch_ucirepo(id=2) 
  
# data (as pandas dataframes) 
X = adult.data.features 
y = adult.data.targets 
  
# metadata 
print(adult.metadata) 
  
# variable information 
print(adult.variables)
# Out:
# Requirement already satisfied: ucimlrepo in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from ucimlrepo) (2.2.3)
# Requirement already satisfied: certifi>=2020.12.5 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from ucimlrepo) (2024.12.14)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\hsapa\box sync\henrique\eia\eia - vscode\tensorflow\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# {'uci_id': 2, 'name': 'Adult', 'repository_url': 'https://archive.ics.uci.edu/dataset/2/adult', 'data_url': 'https://archive.ics.uci.edu/static/public/2/data.csv', 'abstract': 'Predict whether annual income of an individual exceeds $50K/yr based on census data. Also known as "Census Income" dataset. ', 'area': 'Social Science', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 48842, 'num_features': 14, 'feature_types': ['Categorical', 'Integer'], 'demographics': ['Age', 'Income', 'Education Level', 'Other', 'Race', 'Sex'], 'target_col': ['income'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1996, 'last_updated': 'Tue Sep 24 2024', 'dataset_doi': '10.24432/C5XW20', 'creators': ['Barry Becker', 'Ronny Kohavi'], 'intro_paper': None, 'additional_info': {'summary': "Extraction was done by Barry Becker from the 1994 Census database.  A set of reasonably clean records was extracted using the following conditions: ((AAGE>16) && (AGI>100) && (AFNLWGT>1)&& (HRSWK>0))\n\nPrediction task is to determine whether a person's income is over $50,000 a year.\n", 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': 'Listing of attributes:\r\n\r\n>50K, <=50K.\r\n\r\nage: continuous.\r\nworkclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.\r\nfnlwgt: continuous.\r\neducation: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.\r\neducation-num: continuous.\r\nmarital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.\r\noccupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.\r\nrelationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.\r\nrace: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.\r\nsex: Female, Male.\r\ncapital-gain: continuous.\r\ncapital-loss: continuous.\r\nhours-per-week: continuous.\r\nnative-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.', 'citation': None}}
#               name     role         type      demographic  \
# 0              age  Feature      Integer              Age
# 1        workclass  Feature  Categorical           Income
# 2           fnlwgt  Feature      Integer             None
# 3        education  Feature  Categorical  Education Level
# 4    education-num  Feature      Integer  Education Level
# 5   marital-status  Feature  Categorical            Other
# 6       occupation  Feature  Categorical            Other
# 7     relationship  Feature  Categorical            Other
# 8             race  Feature  Categorical             Race
# 9              sex  Feature       Binary              Sex
# 10    capital-gain  Feature      Integer             None
# 11    capital-loss  Feature      Integer             None
# 12  hours-per-week  Feature      Integer             None
# 13  native-country  Feature  Categorical            Other
# 14          income   Target       Binary           Income
#
#                                           description units missing_values
# 0                                                 N/A  None             no
# 1   Private, Self-emp-not-inc, Self-emp-inc, Feder...  None            yes
# 2                                                None  None             no
# 3    Bachelors, Some-college, 11th, HS-grad, Prof-...  None             no
# 4                                                None  None             no
# 5   Married-civ-spouse, Divorced, Never-married, S...  None             no
# 6   Tech-support, Craft-repair, Other-service, Sal...  None            yes
# 7   Wife, Own-child, Husband, Not-in-family, Other...  None             no
# 8   White, Asian-Pac-Islander, Amer-Indian-Eskimo,...  None             no
# 9                                       Female, Male.  None             no
# 10                                               None  None             no
# 11                                               None  None             no
# 12                                               None  None             no
# 13  United-States, Cambodia, England, Puerto-Rico,...  None            yes
# 14                                       >50K, <=50K.  None             no

# %%
X
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48837   39           Private  215419  Bachelors             13
# 48838   64               NaN  321403    HS-grad              9
# 48839   38           Private  374983  Bachelors             13
# 48840   44           Private   83891  Bachelors             13
# 48841   35      Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation    relationship  \
# 0           Never-married       Adm-clerical   Not-in-family
# 1      Married-civ-spouse    Exec-managerial         Husband
# 2                Divorced  Handlers-cleaners   Not-in-family
# 3      Married-civ-spouse  Handlers-cleaners         Husband
# 4      Married-civ-spouse     Prof-specialty            Wife
# ...                   ...                ...             ...
# 48837            Divorced     Prof-specialty   Not-in-family
# 48838             Widowed                NaN  Other-relative
# 48839  Married-civ-spouse     Prof-specialty         Husband
# 48840            Divorced       Adm-clerical       Own-child
# 48841  Married-civ-spouse    Exec-managerial         Husband
#
#                      race     sex  capital-gain  capital-loss  hours-per-week  \
# 0                   White    Male          2174             0              40
# 1                   White    Male             0             0              13
# 2                   White    Male             0             0              40
# 3                   Black    Male             0             0              40
# 4                   Black  Female             0             0              40
# ...                   ...     ...           ...           ...             ...
# 48837               White  Female             0             0              36
# 48838               Black    Male             0             0              40
# 48839               White    Male             0             0              50
# 48840  Asian-Pac-Islander    Male          5455             0              40
# 48841               White    Male             0             0              60
#
#       native-country
# 0      United-States
# 1      United-States
# 2      United-States
# 3      United-States
# 4               Cuba
# ...              ...
# 48837  United-States
# 48838  United-States
# 48839  United-States
# 48840  United-States
# 48841  United-States
#
# [48842 rows x 14 columns]

# %%
y
# Out:
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 48837  <=50K.
# 48838  <=50K.
# 48839  <=50K.
# 48840  <=50K.
# 48841   >50K.
#
# [48842 rows x 1 columns]

# %%
z = pd.concat([X, y], axis=1)
z
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48837   39           Private  215419  Bachelors             13
# 48838   64               NaN  321403    HS-grad              9
# 48839   38           Private  374983  Bachelors             13
# 48840   44           Private   83891  Bachelors             13
# 48841   35      Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation    relationship  \
# 0           Never-married       Adm-clerical   Not-in-family
# 1      Married-civ-spouse    Exec-managerial         Husband
# 2                Divorced  Handlers-cleaners   Not-in-family
# 3      Married-civ-spouse  Handlers-cleaners         Husband
# 4      Married-civ-spouse     Prof-specialty            Wife
# ...                   ...                ...             ...
# 48837            Divorced     Prof-specialty   Not-in-family
# 48838             Widowed                NaN  Other-relative
# 48839  Married-civ-spouse     Prof-specialty         Husband
# 48840            Divorced       Adm-clerical       Own-child
# 48841  Married-civ-spouse    Exec-managerial         Husband
#
#                      race     sex  capital-gain  capital-loss  hours-per-week  \
# 0                   White    Male          2174             0              40
# 1                   White    Male             0             0              13
# 2                   White    Male             0             0              40
# 3                   Black    Male             0             0              40
# 4                   Black  Female             0             0              40
# ...                   ...     ...           ...           ...             ...
# 48837               White  Female             0             0              36
# 48838               Black    Male             0             0              40
# 48839               White    Male             0             0              50
# 48840  Asian-Pac-Islander    Male          5455             0              40
# 48841               White    Male             0             0              60
#
#       native-country  income
# 0      United-States   <=50K
# 1      United-States   <=50K
# 2      United-States   <=50K
# 3      United-States   <=50K
# 4               Cuba   <=50K
# ...              ...     ...
# 48837  United-States  <=50K.
# 48838  United-States  <=50K.
# 48839  United-States  <=50K.
# 48840  United-States  <=50K.
# 48841  United-States   >50K.
#
# [48842 rows x 15 columns]

# %%
z.shape
# Out:
# (48842, 15)

# %%
# We concatenate the X and y dataframes to recreate the single dataframe just to "clean" the row data empity values
# and we exclude the 'fnlwgt' column because it is not relevant for the prediction

z.isnull().sum()
z = z.fillna('None')

z = z.drop(z.loc[(z['workclass'] == 'None')].index)
z = z.drop(z.loc[(z['occupation'] == 'None')].index)
z = z.drop(z.loc[(z['native-country'] == 'None')].index)
#z = z.drop(columns=['fnlwgt'])

print(z.shape)
# Out:
# (47621, 15)

# %%
# We verified the values of the 'income' column needed ajustment

z.loc[z['income'] == '<=50K.', 'income'] = '<=50K'
z.loc[z['income'] == '>50K.', 'income'] = '>50K'
agrupado_y = z.groupby('income').size()
agrupado_y
# Out:
# income
# <=50K    36080
# >50K     11541
# dtype: int64

# %%
X = z.iloc[:, :-1]
y = z.iloc[:, -1]

# %%
# We'll check if there are any missing values in the dataset
# If there are, we'll replace them with the most common value in the column (in case of categorical variables) 
# or the mean (in case of numerical variables)

X.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# dtype: int64

# %%
y.isnull().sum()
# Out:
# np.int64(0)

# %%
# Now we'll check if there any variable with strange value/meaning in each column
# In this case we find some '?' in the columns 'workclass', 'occupation' and 'native-country'
# and we'll replace them with 'Others' as  not expression values

X.loc[X['workclass'] == '?', 'workclass'] = 'Others'
#X.loc[X['workclass'] == 'Never-worked', 'workclass'] = 'Others'
#X.loc[X['workclass'] == 'Without-pay', 'workclass'] = 'Others'

agrupado_workclass = X.groupby(['workclass']).size()
agrupado_workclass
# Out:
# workclass
# Federal-gov          1423
# Local-gov            3126
# Never-worked            7
# Others               1836
# Private             33717
# Self-emp-inc         1688
# Self-emp-not-inc     3838
# State-gov            1965
# Without-pay            21
# dtype: int64

# %%
# We transform all the column values in dummies variables to make the model more accurate

get_workclass = pd.get_dummies(X['workclass'], prefix = 'workclass')
get_workclass
# Out:
#        workclass_Federal-gov  workclass_Local-gov  workclass_Never-worked  \
# 0                      False                False                   False
# 1                      False                False                   False
# 2                      False                False                   False
# 3                      False                False                   False
# 4                      False                False                   False
# ...                      ...                  ...                     ...
# 48836                  False                False                   False
# 48837                  False                False                   False
# 48839                  False                False                   False
# 48840                  False                False                   False
# 48841                  False                False                   False
#
#        workclass_Others  workclass_Private  workclass_Self-emp-inc  \
# 0                 False              False                   False
# 1                 False              False                   False
# 2                 False               True                   False
# 3                 False               True                   False
# 4                 False               True                   False
# ...                 ...                ...                     ...
# 48836             False               True                   False
# 48837             False               True                   False
# 48839             False               True                   False
# 48840             False               True                   False
# 48841             False              False                    True
#
#        workclass_Self-emp-not-inc  workclass_State-gov  workclass_Without-pay
# 0                           False                 True                  False
# 1                            True                False                  False
# 2                           False                False                  False
# 3                           False                False                  False
# 4                           False                False                  False
# ...                           ...                  ...                    ...
# 48836                       False                False                  False
# 48837                       False                False                  False
# 48839                       False                False                  False
# 48840                       False                False                  False
# 48841                       False                False                  False
#
# [47621 rows x 9 columns]

# %%
X.loc[X['occupation'] == '?', 'occupation'] = 'Other-service'
#X.loc[X['occupation'] == 'Armed-Forces', 'occupation'] = 'Other-service'
#X.loc[X['occupation'] == 'Priv-house-serv', 'occupation'] = 'Other-service'
#X.loc[X['occupation'] == 'Protective-serv', 'occupation'] = 'Other-service'
agrupado_occupation = X.groupby(['occupation']).size()
agrupado_occupation
# Out:
# occupation
# Adm-clerical         5589
# Armed-Forces           14
# Craft-repair         6089
# Exec-managerial      6058
# Farming-fishing      1485
# Handlers-cleaners    2066
# Machine-op-inspct    3006
# Other-service        6734
# Priv-house-serv       238
# Prof-specialty       6110
# Protective-serv       981
# Sales                5474
# Tech-support         1436
# Transport-moving     2341
# dtype: int64

# %%
get_occupation = pd.get_dummies(X['occupation'], prefix = 'occupation')
get_occupation
# Out:
#        occupation_Adm-clerical  occupation_Armed-Forces  \
# 0                         True                    False
# 1                        False                    False
# 2                        False                    False
# 3                        False                    False
# 4                        False                    False
# ...                        ...                      ...
# 48836                    False                    False
# 48837                    False                    False
# 48839                    False                    False
# 48840                     True                    False
# 48841                    False                    False
#
#        occupation_Craft-repair  occupation_Exec-managerial  \
# 0                        False                       False
# 1                        False                        True
# 2                        False                       False
# 3                        False                       False
# 4                        False                       False
# ...                        ...                         ...
# 48836                    False                       False
# 48837                    False                       False
# 48839                    False                       False
# 48840                    False                       False
# 48841                    False                        True
#
#        occupation_Farming-fishing  occupation_Handlers-cleaners  \
# 0                           False                         False
# 1                           False                         False
# 2                           False                          True
# 3                           False                          True
# 4                           False                         False
# ...                           ...                           ...
# 48836                       False                         False
# 48837                       False                         False
# 48839                       False                         False
# 48840                       False                         False
# 48841                       False                         False
#
#        occupation_Machine-op-inspct  occupation_Other-service  \
# 0                             False                     False
# 1                             False                     False
# 2                             False                     False
# 3                             False                     False
# 4                             False                     False
# ...                             ...                       ...
# 48836                         False                     False
# 48837                         False                     False
# 48839                         False                     False
# 48840                         False                     False
# 48841                         False                     False
#
#        occupation_Priv-house-serv  occupation_Prof-specialty  \
# 0                           False                      False
# 1                           False                      False
# 2                           False                      False
# 3                           False                      False
# 4                           False                       True
# ...                           ...                        ...
# 48836                       False                       True
# 48837                       False                       True
# 48839                       False                       True
# 48840                       False                      False
# 48841                       False                      False
#
#        occupation_Protective-serv  occupation_Sales  occupation_Tech-support  \
# 0                           False             False                    False
# 1                           False             False                    False
# 2                           False             False                    False
# 3                           False             False                    False
# 4                           False             False                    False
# ...                           ...               ...                      ...
# 48836                       False             False                    False
# 48837                       False             False                    False
# 48839                       False             False                    False
# 48840                       False             False                    False
# 48841                       False             False                    False
#
#        occupation_Transport-moving
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
# ...                            ...
# 48836                        False
# 48837                        False
# 48839                        False
# 48840                        False
# 48841                        False
#
# [47621 rows x 14 columns]

# %%
# In 'native-country' behond the '?' we'll replace all the countries that are not United-States or Mexico with 'Others'

X.loc[X['native-country'] == '?', 'native-country'] = 'Others'

#for index, row in X.iterrows():
#  if row['native-country'] == 'United-States':
#    continue
#  elif row['native-country'] == 'Mexico':
#    continue
#  else:
#    X.at[index, 'native-country'] = 'Others'

agrupado_country = X.groupby(['native-country']).size()
agrupado_country
# Out:
# native-country
# Cambodia                         27
# Canada                          177
# China                           120
# Columbia                         85
# Cuba                            136
# Dominican-Republic              100
# Ecuador                          44
# El-Salvador                     153
# England                         123
# France                           38
# Germany                         202
# Greece                           49
# Guatemala                        87
# Haiti                            71
# Holand-Netherlands                1
# Honduras                         20
# Hong                             29
# Hungary                          18
# India                           147
# Iran                             57
# Ireland                          36
# Italy                           105
# Jamaica                         104
# Japan                            92
# Laos                             22
# Mexico                          936
# Nicaragua                        49
# Others                          583
# Outlying-US(Guam-USVI-etc)       22
# Peru                             46
# Philippines                     293
# Poland                           85
# Portugal                         65
# Puerto-Rico                     180
# Scotland                         21
# South                           110
# Taiwan                           64
# Thailand                         30
# Trinadad&Tobago                  27
# United-States                 42958
# Vietnam                          86
# Yugoslavia                       23
# dtype: int64

# %%
get_native_country = pd.get_dummies(X['native-country'], prefix = 'native-country')
get_native_country
# Out:
#        native-country_Cambodia  native-country_Canada  native-country_China  \
# 0                        False                  False                 False
# 1                        False                  False                 False
# 2                        False                  False                 False
# 3                        False                  False                 False
# 4                        False                  False                 False
# ...                        ...                    ...                   ...
# 48836                    False                  False                 False
# 48837                    False                  False                 False
# 48839                    False                  False                 False
# 48840                    False                  False                 False
# 48841                    False                  False                 False
#
#        native-country_Columbia  native-country_Cuba  \
# 0                        False                False
# 1                        False                False
# 2                        False                False
# 3                        False                False
# 4                        False                 True
# ...                        ...                  ...
# 48836                    False                False
# 48837                    False                False
# 48839                    False                False
# 48840                    False                False
# 48841                    False                False
#
#        native-country_Dominican-Republic  native-country_Ecuador  \
# 0                                  False                   False
# 1                                  False                   False
# 2                                  False                   False
# 3                                  False                   False
# 4                                  False                   False
# ...                                  ...                     ...
# 48836                              False                   False
# 48837                              False                   False
# 48839                              False                   False
# 48840                              False                   False
# 48841                              False                   False
#
#        native-country_El-Salvador  native-country_England  \
# 0                           False                   False
# 1                           False                   False
# 2                           False                   False
# 3                           False                   False
# 4                           False                   False
# ...                           ...                     ...
# 48836                       False                   False
# 48837                       False                   False
# 48839                       False                   False
# 48840                       False                   False
# 48841                       False                   False
#
#        native-country_France  ...  native-country_Portugal  \
# 0                      False  ...                    False
# 1                      False  ...                    False
# 2                      False  ...                    False
# 3                      False  ...                    False
# 4                      False  ...                    False
# ...                      ...  ...                      ...
# 48836                  False  ...                    False
# 48837                  False  ...                    False
# 48839                  False  ...                    False
# 48840                  False  ...                    False
# 48841                  False  ...                    False
#
#        native-country_Puerto-Rico  native-country_Scotland  \
# 0                           False                    False
# 1                           False                    False
# 2                           False                    False
# 3                           False                    False
# 4                           False                    False
# ...                           ...                      ...
# 48836                       False                    False
# 48837                       False                    False
# 48839                       False                    False
# 48840                       False                    False
# 48841                       False                    False
#
#        native-country_South  native-country_Taiwan  native-country_Thailand  \
# 0                     False                  False                    False
# 1                     False                  False                    False
# 2                     False                  False                    False
# 3                     False                  False                    False
# 4                     False                  False                    False
# ...                     ...                    ...                      ...
# 48836                 False                  False                    False
# 48837                 False                  False                    False
# 48839                 False                  False                    False
# 48840                 False                  False                    False
# 48841                 False                  False                    False
#
#        native-country_Trinadad&Tobago  native-country_United-States  \
# 0                               False                          True
# 1                               False                          True
# 2                               False                          True
# 3                               False                          True
# 4                               False                         False
# ...                               ...                           ...
# 48836                           False                          True
# 48837                           False                          True
# 48839                           False                          True
# 48840                           False                          True
# 48841                           False                          True
#
#        native-country_Vietnam  native-country_Yugoslavia
# 0                       False                      False
# 1                       False                      False
# 2                       False                      False
# 3                       False                      False
# 4                       False                      False
# ...                       ...                        ...
# 48836                   False                      False
# 48837                   False                      False
# 48839                   False                      False
# 48840                   False                      False
# 48841                   False                      False
#
# [47621 rows x 42 columns]

# %%
agrupado_education = X.groupby(['education']).size()
agrupado_education
# Out:
# education
# 10th             1336
# 11th             1746
# 12th              633
# 1st-4th           239
# 5th-6th           494
# 7th-8th           912
# 9th               735
# Assoc-acdm       1566
# Assoc-voc        2034
# Bachelors        7881
# Doctorate         582
# HS-grad         15444
# Masters          2610
# Preschool          78
# Prof-school       819
# Some-college    10512
# dtype: int64

# %%
#X.loc[X['education-num'] == 10, 'education-num'] = 'Others'
#X.loc[X['education-num'].isin([1,2,3,4,5,6,7,8,9]), 'education-num'] = 'Basic-Level'
#X.loc[X['education-num'].isin([11,12,13,14,15,16]), 'education-num'] = 'High-Level'
agrupado_education_num = X.groupby(['education-num']).size()
agrupado_education_num
# Out:
# education-num
# 1        78
# 2       239
# 3       494
# 4       912
# 5       735
# 6      1336
# 7      1746
# 8       633
# 9     15444
# 10    10512
# 11     2034
# 12     1566
# 13     7881
# 14     2610
# 15      819
# 16      582
# dtype: int64

# %%
get_education_num = pd.get_dummies(X['education-num'], prefix = 'education-num')
get_education_num
# Out:
#        education-num_1  education-num_2  education-num_3  education-num_4  \
# 0                False            False            False            False
# 1                False            False            False            False
# 2                False            False            False            False
# 3                False            False            False            False
# 4                False            False            False            False
# ...                ...              ...              ...              ...
# 48836            False            False            False            False
# 48837            False            False            False            False
# 48839            False            False            False            False
# 48840            False            False            False            False
# 48841            False            False            False            False
#
#        education-num_5  education-num_6  education-num_7  education-num_8  \
# 0                False            False            False            False
# 1                False            False            False            False
# 2                False            False            False            False
# 3                False            False             True            False
# 4                False            False            False            False
# ...                ...              ...              ...              ...
# 48836            False            False            False            False
# 48837            False            False            False            False
# 48839            False            False            False            False
# 48840            False            False            False            False
# 48841            False            False            False            False
#
#        education-num_9  education-num_10  education-num_11  education-num_12  \
# 0                False             False             False             False
# 1                False             False             False             False
# 2                 True             False             False             False
# 3                False             False             False             False
# 4                False             False             False             False
# ...                ...               ...               ...               ...
# 48836            False             False             False             False
# 48837            False             False             False             False
# 48839            False             False             False             False
# 48840            False             False             False             False
# 48841            False             False             False             False
#
#        education-num_13  education-num_14  education-num_15  education-num_16
# 0                  True             False             False             False
# 1                  True             False             False             False
# 2                 False             False             False             False
# 3                 False             False             False             False
# 4                  True             False             False             False
# ...                 ...               ...               ...               ...
# 48836              True             False             False             False
# 48837              True             False             False             False
# 48839              True             False             False             False
# 48840              True             False             False             False
# 48841              True             False             False             False
#
# [47621 rows x 16 columns]

# %%
#X.loc[X['marital-status'] == 'Married-AF-spouse', 'marital-status'] = 'Others'
#X.loc[X['marital-status'] == 'Married-spouse-absent', 'marital-status'] = 'Others'
#X.loc[X['marital-status'] == 'Separated', 'marital-status'] = 'Others'
#X.loc[X['marital-status'] == 'Widowed ', 'marital-status'] = 'Others'
agrupado_marital_status = X.groupby(['marital-status']).size()
agrupado_marital_status
# Out:
# marital-status
# Divorced                  6526
# Married-AF-spouse           34
# Married-civ-spouse       21966
# Married-spouse-absent      600
# Never-married            15555
# Separated                 1497
# Widowed                   1443
# dtype: int64

# %%
get_marital_status = pd.get_dummies(X['marital-status'], prefix = 'marital-status')
get_marital_status
# Out:
#        marital-status_Divorced  marital-status_Married-AF-spouse  \
# 0                        False                             False
# 1                        False                             False
# 2                         True                             False
# 3                        False                             False
# 4                        False                             False
# ...                        ...                               ...
# 48836                    False                             False
# 48837                     True                             False
# 48839                    False                             False
# 48840                     True                             False
# 48841                    False                             False
#
#        marital-status_Married-civ-spouse  \
# 0                                  False
# 1                                   True
# 2                                  False
# 3                                   True
# 4                                   True
# ...                                  ...
# 48836                              False
# 48837                              False
# 48839                               True
# 48840                              False
# 48841                               True
#
#        marital-status_Married-spouse-absent  marital-status_Never-married  \
# 0                                     False                          True
# 1                                     False                         False
# 2                                     False                         False
# 3                                     False                         False
# 4                                     False                         False
# ...                                     ...                           ...
# 48836                                 False                          True
# 48837                                 False                         False
# 48839                                 False                         False
# 48840                                 False                         False
# 48841                                 False                         False
#
#        marital-status_Separated  marital-status_Widowed
# 0                         False                   False
# 1                         False                   False
# 2                         False                   False
# 3                         False                   False
# 4                         False                   False
# ...                         ...                     ...
# 48836                     False                   False
# 48837                     False                   False
# 48839                     False                   False
# 48840                     False                   False
# 48841                     False                   False
#
# [47621 rows x 7 columns]

# %%
agrupado_relationship = X.groupby(['relationship']).size()
agrupado_relationship
# Out:
# relationship
# Husband           19396
# Not-in-family     12281
# Other-relative     1441
# Own-child          7228
# Unmarried          5022
# Wife               2253
# dtype: int64

# %%
get_relationship = pd.get_dummies(X['relationship'], prefix = 'relationship')
get_relationship
# Out:
#        relationship_Husband  relationship_Not-in-family  \
# 0                     False                        True
# 1                      True                       False
# 2                     False                        True
# 3                      True                       False
# 4                     False                       False
# ...                     ...                         ...
# 48836                 False                       False
# 48837                 False                        True
# 48839                  True                       False
# 48840                 False                       False
# 48841                  True                       False
#
#        relationship_Other-relative  relationship_Own-child  \
# 0                            False                   False
# 1                            False                   False
# 2                            False                   False
# 3                            False                   False
# 4                            False                   False
# ...                            ...                     ...
# 48836                        False                    True
# 48837                        False                   False
# 48839                        False                   False
# 48840                        False                    True
# 48841                        False                   False
#
#        relationship_Unmarried  relationship_Wife
# 0                       False              False
# 1                       False              False
# 2                       False              False
# 3                       False              False
# 4                       False               True
# ...                       ...                ...
# 48836                   False              False
# 48837                   False              False
# 48839                   False              False
# 48840                   False              False
# 48841                   False              False
#
# [47621 rows x 6 columns]

# %%
#X.loc[X['race'] == 'Amer-Indian-Eskimo', 'race'] = 'Other'
#X.loc[X['race'] == 'Asian-Pac-Islander', 'race'] = 'Other'
agrupado_race = X.groupby(['race']).size()
agrupado_race
# Out:
# race
# Amer-Indian-Eskimo      460
# Asian-Pac-Islander     1447
# Black                  4535
# Other                   393
# White                 40786
# dtype: int64

# %%
get_race = pd.get_dummies(X['race'], prefix = 'race')
get_race
# Out:
#        race_Amer-Indian-Eskimo  race_Asian-Pac-Islander  race_Black  \
# 0                        False                    False       False
# 1                        False                    False       False
# 2                        False                    False       False
# 3                        False                    False        True
# 4                        False                    False        True
# ...                        ...                      ...         ...
# 48836                    False                    False       False
# 48837                    False                    False       False
# 48839                    False                    False       False
# 48840                    False                     True       False
# 48841                    False                    False       False
#
#        race_Other  race_White
# 0           False        True
# 1           False        True
# 2           False        True
# 3           False       False
# 4           False       False
# ...           ...         ...
# 48836       False        True
# 48837       False        True
# 48839       False        True
# 48840       False       False
# 48841       False        True
#
# [47621 rows x 5 columns]

# %%
agrupado_sex = X.groupby(['sex']).size()
agrupado_sex
# Out:
# sex
# Female    15684
# Male      31937
# dtype: int64

# %%
get_sex = pd.get_dummies(X['sex'], prefix = 'sex')
get_sex
# Out:
#        sex_Female  sex_Male
# 0           False      True
# 1           False      True
# 2           False      True
# 3           False      True
# 4            True     False
# ...           ...       ...
# 48836       False      True
# 48837        True     False
# 48839       False      True
# 48840       False      True
# 48841       False      True
#
# [47621 rows x 2 columns]

# %%
# In 'capital-gain', as like 'capital loss' and 'hours-per-week', we'll group the value in smaller 'clusters' 
# to have a better understanding, minimizing the number of unique values and eliminating the outliers

#X['capital-gain'] = pd.to_numeric(X['capital-gain'], errors='coerce')
#for index, row in X.iterrows():
#  if 0 < row['capital-gain'] <= 100000:
#    X.at[index, 'capital-gain'] = 'Up to 100k'
#  elif row['capital-gain'] > 100000:
#    X.at[index, 'capital-gain'] = 'More than 100k'
#  else:
#    X.at[index, 'capital-gain'] = '0'

agrupado_capital_gain = X.groupby(['capital-gain']).size()
agrupado_capital_gain
# Out:
# capital-gain
# 0        43657
# 114          8
# 401          3
# 594         48
# 914         10
#          ...
# 25236       14
# 27828       58
# 34095        6
# 41310        3
# 99999      240
# Length: 122, dtype: int64

# %%
get_capital_gain = pd.get_dummies(X['capital-gain'], prefix = 'capital-gain')
get_capital_gain
# Out:
#        capital-gain_0  capital-gain_114  capital-gain_401  capital-gain_594  \
# 0               False             False             False             False
# 1                True             False             False             False
# 2                True             False             False             False
# 3                True             False             False             False
# 4                True             False             False             False
# ...               ...               ...               ...               ...
# 48836            True             False             False             False
# 48837            True             False             False             False
# 48839            True             False             False             False
# 48840           False             False             False             False
# 48841            True             False             False             False
#
#        capital-gain_914  capital-gain_991  capital-gain_1055  \
# 0                 False             False              False
# 1                 False             False              False
# 2                 False             False              False
# 3                 False             False              False
# 4                 False             False              False
# ...                 ...               ...                ...
# 48836             False             False              False
# 48837             False             False              False
# 48839             False             False              False
# 48840             False             False              False
# 48841             False             False              False
#
#        capital-gain_1086  capital-gain_1111  capital-gain_1151  ...  \
# 0                  False              False              False  ...
# 1                  False              False              False  ...
# 2                  False              False              False  ...
# 3                  False              False              False  ...
# 4                  False              False              False  ...
# ...                  ...                ...                ...  ...
# 48836              False              False              False  ...
# 48837              False              False              False  ...
# 48839              False              False              False  ...
# 48840              False              False              False  ...
# 48841              False              False              False  ...
#
#        capital-gain_15831  capital-gain_18481  capital-gain_20051  \
# 0                   False               False               False
# 1                   False               False               False
# 2                   False               False               False
# 3                   False               False               False
# 4                   False               False               False
# ...                   ...                 ...                 ...
# 48836               False               False               False
# 48837               False               False               False
# 48839               False               False               False
# 48840               False               False               False
# 48841               False               False               False
#
#        capital-gain_22040  capital-gain_25124  capital-gain_25236  \
# 0                   False               False               False
# 1                   False               False               False
# 2                   False               False               False
# 3                   False               False               False
# 4                   False               False               False
# ...                   ...                 ...                 ...
# 48836               False               False               False
# 48837               False               False               False
# 48839               False               False               False
# 48840               False               False               False
# 48841               False               False               False
#
#        capital-gain_27828  capital-gain_34095  capital-gain_41310  \
# 0                   False               False               False
# 1                   False               False               False
# 2                   False               False               False
# 3                   False               False               False
# 4                   False               False               False
# ...                   ...                 ...                 ...
# 48836               False               False               False
# 48837               False               False               False
# 48839               False               False               False
# 48840               False               False               False
# 48841               False               False               False
#
#        capital-gain_99999
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 48836               False
# 48837               False
# 48839               False
# 48840               False
# 48841               False
#
# [47621 rows x 122 columns]

# %%
#X['capital-loss'] = pd.to_numeric(X['capital-loss'], errors='coerce')
#for index, row in X.iterrows():
#  if 0 < row['capital-loss'] <= 5000:
#    X.at[index, 'capital-loss'] = 'Up to 5k'
#  elif row['capital-loss'] > 5000:
#    X.at[index, 'capital-loss'] = 'More than 5k'
#  else:
#    X.at[index, 'capital-loss'] = '0'

agrupado_capital_loss = X.groupby(['capital-loss']).size()
agrupado_capital_loss
# Out:
# capital-loss
# 0       45389
# 155         1
# 213         5
# 323         5
# 419         3
#         ...
# 3175        2
# 3683        2
# 3770        4
# 3900        2
# 4356        3
# Length: 98, dtype: int64

# %%
get_capital_loss = pd.get_dummies(X['capital-loss'], prefix = 'capital-loss')
get_capital_loss
# Out:
#        capital-loss_0  capital-loss_155  capital-loss_213  capital-loss_323  \
# 0                True             False             False             False
# 1                True             False             False             False
# 2                True             False             False             False
# 3                True             False             False             False
# 4                True             False             False             False
# ...               ...               ...               ...               ...
# 48836            True             False             False             False
# 48837            True             False             False             False
# 48839            True             False             False             False
# 48840            True             False             False             False
# 48841            True             False             False             False
#
#        capital-loss_419  capital-loss_625  capital-loss_653  capital-loss_810  \
# 0                 False             False             False             False
# 1                 False             False             False             False
# 2                 False             False             False             False
# 3                 False             False             False             False
# 4                 False             False             False             False
# ...                 ...               ...               ...               ...
# 48836             False             False             False             False
# 48837             False             False             False             False
# 48839             False             False             False             False
# 48840             False             False             False             False
# 48841             False             False             False             False
#
#        capital-loss_880  capital-loss_974  ...  capital-loss_2559  \
# 0                 False             False  ...              False
# 1                 False             False  ...              False
# 2                 False             False  ...              False
# 3                 False             False  ...              False
# 4                 False             False  ...              False
# ...                 ...               ...  ...                ...
# 48836             False             False  ...              False
# 48837             False             False  ...              False
# 48839             False             False  ...              False
# 48840             False             False  ...              False
# 48841             False             False  ...              False
#
#        capital-loss_2603  capital-loss_2754  capital-loss_2824  \
# 0                  False              False              False
# 1                  False              False              False
# 2                  False              False              False
# 3                  False              False              False
# 4                  False              False              False
# ...                  ...                ...                ...
# 48836              False              False              False
# 48837              False              False              False
# 48839              False              False              False
# 48840              False              False              False
# 48841              False              False              False
#
#        capital-loss_3004  capital-loss_3175  capital-loss_3683  \
# 0                  False              False              False
# 1                  False              False              False
# 2                  False              False              False
# 3                  False              False              False
# 4                  False              False              False
# ...                  ...                ...                ...
# 48836              False              False              False
# 48837              False              False              False
# 48839              False              False              False
# 48840              False              False              False
# 48841              False              False              False
#
#        capital-loss_3770  capital-loss_3900  capital-loss_4356
# 0                  False              False              False
# 1                  False              False              False
# 2                  False              False              False
# 3                  False              False              False
# 4                  False              False              False
# ...                  ...                ...                ...
# 48836              False              False              False
# 48837              False              False              False
# 48839              False              False              False
# 48840              False              False              False
# 48841              False              False              False
#
# [47621 rows x 98 columns]

# %%
#X['hours-per-week'] = pd.to_numeric(X['hours-per-week'], errors='coerce')
#for index, row in X.iterrows():
#  if row['hours-per-week'] == 0:
#    X.at[index, 'hours-per-week'] = '0'
#  elif 0 < row['hours-per-week'] <= 40:
#    X.at[index, 'hours-per-week'] = 'Up to 40h'
#  elif row['hours-per-week'] > 40:
#    X.at[index, 'hours-per-week'] = 'More than 40h'

agrupado_hours_per_week = X.groupby(['hours-per-week']).size()
agrupado_hours_per_week
# Out:
# hours-per-week
# 1      25
# 2      41
# 3      50
# 4      74
# 5      82
#      ...
# 95      2
# 96      9
# 97      2
# 98     14
# 99    130
# Length: 96, dtype: int64

# %%
get_hours_per_week = pd.get_dummies(X['hours-per-week'], prefix = 'hours-per-week')
get_hours_per_week
# Out:
#        hours-per-week_1  hours-per-week_2  hours-per-week_3  hours-per-week_4  \
# 0                 False             False             False             False
# 1                 False             False             False             False
# 2                 False             False             False             False
# 3                 False             False             False             False
# 4                 False             False             False             False
# ...                 ...               ...               ...               ...
# 48836             False             False             False             False
# 48837             False             False             False             False
# 48839             False             False             False             False
# 48840             False             False             False             False
# 48841             False             False             False             False
#
#        hours-per-week_5  hours-per-week_6  hours-per-week_7  hours-per-week_8  \
# 0                 False             False             False             False
# 1                 False             False             False             False
# 2                 False             False             False             False
# 3                 False             False             False             False
# 4                 False             False             False             False
# ...                 ...               ...               ...               ...
# 48836             False             False             False             False
# 48837             False             False             False             False
# 48839             False             False             False             False
# 48840             False             False             False             False
# 48841             False             False             False             False
#
#        hours-per-week_9  hours-per-week_10  ...  hours-per-week_89  \
# 0                 False              False  ...              False
# 1                 False              False  ...              False
# 2                 False              False  ...              False
# 3                 False              False  ...              False
# 4                 False              False  ...              False
# ...                 ...                ...  ...                ...
# 48836             False              False  ...              False
# 48837             False              False  ...              False
# 48839             False              False  ...              False
# 48840             False              False  ...              False
# 48841             False              False  ...              False
#
#        hours-per-week_90  hours-per-week_91  hours-per-week_92  \
# 0                  False              False              False
# 1                  False              False              False
# 2                  False              False              False
# 3                  False              False              False
# 4                  False              False              False
# ...                  ...                ...                ...
# 48836              False              False              False
# 48837              False              False              False
# 48839              False              False              False
# 48840              False              False              False
# 48841              False              False              False
#
#        hours-per-week_94  hours-per-week_95  hours-per-week_96  \
# 0                  False              False              False
# 1                  False              False              False
# 2                  False              False              False
# 3                  False              False              False
# 4                  False              False              False
# ...                  ...                ...                ...
# 48836              False              False              False
# 48837              False              False              False
# 48839              False              False              False
# 48840              False              False              False
# 48841              False              False              False
#
#        hours-per-week_97  hours-per-week_98  hours-per-week_99
# 0                  False              False              False
# 1                  False              False              False
# 2                  False              False              False
# 3                  False              False              False
# 4                  False              False              False
# ...                  ...                ...                ...
# 48836              False              False              False
# 48837              False              False              False
# 48839              False              False              False
# 48840              False              False              False
# 48841              False              False              False
#
# [47621 rows x 96 columns]

# %%
# We'll standarlizer the numerical variables in a smaller range

standarscaler = StandardScaler()
numerical = X.select_dtypes(include=['int64','float64']).columns
X[numerical] = standarscaler.fit_transform(X[numerical])
X
# Out:
#             age         workclass    fnlwgt  education  education-num  \
# 0      0.026501         State-gov -1.062924  Bachelors       1.132729
# 1      0.837781  Self-emp-not-inc -1.008031  Bachelors       1.132729
# 2     -0.047252           Private  0.245517    HS-grad      -0.424726
# 3      1.059039           Private  0.426206       11th      -1.203454
# 4     -0.784780           Private  1.408394  Bachelors       1.132729
# ...         ...               ...       ...        ...            ...
# 48836 -0.416016           Private  0.525573  Bachelors       1.132729
# 48837  0.026501           Private  0.243367  Bachelors       1.132729
# 48839 -0.047252           Private  1.754843  Bachelors       1.132729
# 48840  0.395264           Private -1.002537  Bachelors       1.132729
# 48841 -0.268510      Self-emp-inc -0.071794  Bachelors       1.132729
#
#            marital-status         occupation   relationship  \
# 0           Never-married       Adm-clerical  Not-in-family
# 1      Married-civ-spouse    Exec-managerial        Husband
# 2                Divorced  Handlers-cleaners  Not-in-family
# 3      Married-civ-spouse  Handlers-cleaners        Husband
# 4      Married-civ-spouse     Prof-specialty           Wife
# ...                   ...                ...            ...
# 48836       Never-married     Prof-specialty      Own-child
# 48837            Divorced     Prof-specialty  Not-in-family
# 48839  Married-civ-spouse     Prof-specialty        Husband
# 48840            Divorced       Adm-clerical      Own-child
# 48841  Married-civ-spouse    Exec-managerial        Husband
#
#                      race     sex  capital-gain  capital-loss  hours-per-week  \
# 0                   White    Male      0.144629     -0.217456       -0.048943
# 1                   White    Male     -0.145735     -0.217456       -2.251188
# 2                   White    Male     -0.145735     -0.217456       -0.048943
# 3                   Black    Male     -0.145735     -0.217456       -0.048943
# 4                   Black  Female     -0.145735     -0.217456       -0.048943
# ...                   ...     ...           ...           ...             ...
# 48836               White    Male     -0.145735     -0.217456       -0.048943
# 48837               White  Female     -0.145735     -0.217456       -0.375201
# 48839               White    Male     -0.145735     -0.217456        0.766703
# 48840  Asian-Pac-Islander    Male      0.582847     -0.217456       -0.048943
# 48841               White    Male     -0.145735     -0.217456        1.582350
#
#       native-country
# 0      United-States
# 1      United-States
# 2      United-States
# 3      United-States
# 4               Cuba
# ...              ...
# 48836  United-States
# 48837  United-States
# 48839  United-States
# 48840  United-States
# 48841  United-States
#
# [47621 rows x 14 columns]

# %%
# We transform categorical variables into numerical variables using the LabelEncoder, and we encode as well the X_ajusted and y dataframes

labelencoder = LabelEncoder()

X = X.drop(columns=['education-num'])

for column in X.select_dtypes(include=['object']).columns:
  X[column] = labelencoder.fit_transform(X[column])

X
# Out:
#             age  workclass    fnlwgt  education  marital-status  occupation  \
# 0      0.026501          7 -1.062924          9               4           0
# 1      0.837781          6 -1.008031          9               2           3
# 2     -0.047252          4  0.245517         11               0           5
# 3      1.059039          4  0.426206          1               2           5
# 4     -0.784780          4  1.408394          9               2           9
# ...         ...        ...       ...        ...             ...         ...
# 48836 -0.416016          4  0.525573          9               4           9
# 48837  0.026501          4  0.243367          9               0           9
# 48839 -0.047252          4  1.754843          9               2           9
# 48840  0.395264          4 -1.002537          9               0           0
# 48841 -0.268510          5 -0.071794          9               2           3
#
#        relationship  race  sex  capital-gain  capital-loss  hours-per-week  \
# 0                 1     4    1      0.144629     -0.217456       -0.048943
# 1                 0     4    1     -0.145735     -0.217456       -2.251188
# 2                 1     4    1     -0.145735     -0.217456       -0.048943
# 3                 0     2    1     -0.145735     -0.217456       -0.048943
# 4                 5     2    0     -0.145735     -0.217456       -0.048943
# ...             ...   ...  ...           ...           ...             ...
# 48836             3     4    1     -0.145735     -0.217456       -0.048943
# 48837             1     4    0     -0.145735     -0.217456       -0.375201
# 48839             0     4    1     -0.145735     -0.217456        0.766703
# 48840             3     1    1      0.582847     -0.217456       -0.048943
# 48841             0     4    1     -0.145735     -0.217456        1.582350
#
#        native-country
# 0                  39
# 1                  39
# 2                  39
# 3                  39
# 4                   4
# ...               ...
# 48836              39
# 48837              39
# 48839              39
# 48840              39
# 48841              39
#
# [47621 rows x 13 columns]

# %%
# We created a new dataframe of X with all the dummies variables

X_ajusted = pd.concat([X['age'],
                       get_workclass,
                       get_education_num,
                       get_marital_status,
                       get_occupation,
                       get_relationship,
                       get_race,
                       get_sex,
                       get_capital_gain,
                       get_capital_loss,
                       get_hours_per_week,
                       get_native_country,
                       ], axis=1)
X_ajusted
# Out:
#             age  workclass_Federal-gov  workclass_Local-gov  \
# 0      0.026501                  False                False
# 1      0.837781                  False                False
# 2     -0.047252                  False                False
# 3      1.059039                  False                False
# 4     -0.784780                  False                False
# ...         ...                    ...                  ...
# 48836 -0.416016                  False                False
# 48837  0.026501                  False                False
# 48839 -0.047252                  False                False
# 48840  0.395264                  False                False
# 48841 -0.268510                  False                False
#
#        workclass_Never-worked  workclass_Others  workclass_Private  \
# 0                       False             False              False
# 1                       False             False              False
# 2                       False             False               True
# 3                       False             False               True
# 4                       False             False               True
# ...                       ...               ...                ...
# 48836                   False             False               True
# 48837                   False             False               True
# 48839                   False             False               True
# 48840                   False             False               True
# 48841                   False             False              False
#
#        workclass_Self-emp-inc  workclass_Self-emp-not-inc  \
# 0                       False                       False
# 1                       False                        True
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
# ...                       ...                         ...
# 48836                   False                       False
# 48837                   False                       False
# 48839                   False                       False
# 48840                   False                       False
# 48841                    True                       False
#
#        workclass_State-gov  workclass_Without-pay  ...  \
# 0                     True                  False  ...
# 1                    False                  False  ...
# 2                    False                  False  ...
# 3                    False                  False  ...
# 4                    False                  False  ...
# ...                    ...                    ...  ...
# 48836                False                  False  ...
# 48837                False                  False  ...
# 48839                False                  False  ...
# 48840                False                  False  ...
# 48841                False                  False  ...
#
#        native-country_Portugal  native-country_Puerto-Rico  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                       False
# 4                        False                       False
# ...                        ...                         ...
# 48836                    False                       False
# 48837                    False                       False
# 48839                    False                       False
# 48840                    False                       False
# 48841                    False                       False
#
#        native-country_Scotland  native-country_South  native-country_Taiwan  \
# 0                        False                 False                  False
# 1                        False                 False                  False
# 2                        False                 False                  False
# 3                        False                 False                  False
# 4                        False                 False                  False
# ...                        ...                   ...                    ...
# 48836                    False                 False                  False
# 48837                    False                 False                  False
# 48839                    False                 False                  False
# 48840                    False                 False                  False
# 48841                    False                 False                  False
#
#        native-country_Thailand  native-country_Trinadad&Tobago  \
# 0                        False                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                           False
# 4                        False                           False
# ...                        ...                             ...
# 48836                    False                           False
# 48837                    False                           False
# 48839                    False                           False
# 48840                    False                           False
# 48841                    False                           False
#
#        native-country_United-States  native-country_Vietnam  \
# 0                              True                   False
# 1                              True                   False
# 2                              True                   False
# 3                              True                   False
# 4                             False                   False
# ...                             ...                     ...
# 48836                          True                   False
# 48837                          True                   False
# 48839                          True                   False
# 48840                          True                   False
# 48841                          True                   False
#
#        native-country_Yugoslavia
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 48836                      False
# 48837                      False
# 48839                      False
# 48840                      False
# 48841                      False
#
# [47621 rows x 418 columns]

# %%
labelencoder = LabelEncoder()

for column in X_ajusted.select_dtypes(include=['object']).columns:
  X_ajusted[column] = labelencoder.fit_transform(X_ajusted[column])

X_ajusted
# Out:
#             age  workclass_Federal-gov  workclass_Local-gov  \
# 0      0.026501                  False                False
# 1      0.837781                  False                False
# 2     -0.047252                  False                False
# 3      1.059039                  False                False
# 4     -0.784780                  False                False
# ...         ...                    ...                  ...
# 48836 -0.416016                  False                False
# 48837  0.026501                  False                False
# 48839 -0.047252                  False                False
# 48840  0.395264                  False                False
# 48841 -0.268510                  False                False
#
#        workclass_Never-worked  workclass_Others  workclass_Private  \
# 0                       False             False              False
# 1                       False             False              False
# 2                       False             False               True
# 3                       False             False               True
# 4                       False             False               True
# ...                       ...               ...                ...
# 48836                   False             False               True
# 48837                   False             False               True
# 48839                   False             False               True
# 48840                   False             False               True
# 48841                   False             False              False
#
#        workclass_Self-emp-inc  workclass_Self-emp-not-inc  \
# 0                       False                       False
# 1                       False                        True
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
# ...                       ...                         ...
# 48836                   False                       False
# 48837                   False                       False
# 48839                   False                       False
# 48840                   False                       False
# 48841                    True                       False
#
#        workclass_State-gov  workclass_Without-pay  ...  \
# 0                     True                  False  ...
# 1                    False                  False  ...
# 2                    False                  False  ...
# 3                    False                  False  ...
# 4                    False                  False  ...
# ...                    ...                    ...  ...
# 48836                False                  False  ...
# 48837                False                  False  ...
# 48839                False                  False  ...
# 48840                False                  False  ...
# 48841                False                  False  ...
#
#        native-country_Portugal  native-country_Puerto-Rico  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                       False
# 4                        False                       False
# ...                        ...                         ...
# 48836                    False                       False
# 48837                    False                       False
# 48839                    False                       False
# 48840                    False                       False
# 48841                    False                       False
#
#        native-country_Scotland  native-country_South  native-country_Taiwan  \
# 0                        False                 False                  False
# 1                        False                 False                  False
# 2                        False                 False                  False
# 3                        False                 False                  False
# 4                        False                 False                  False
# ...                        ...                   ...                    ...
# 48836                    False                 False                  False
# 48837                    False                 False                  False
# 48839                    False                 False                  False
# 48840                    False                 False                  False
# 48841                    False                 False                  False
#
#        native-country_Thailand  native-country_Trinadad&Tobago  \
# 0                        False                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                           False
# 4                        False                           False
# ...                        ...                             ...
# 48836                    False                           False
# 48837                    False                           False
# 48839                    False                           False
# 48840                    False                           False
# 48841                    False                           False
#
#        native-country_United-States  native-country_Vietnam  \
# 0                              True                   False
# 1                              True                   False
# 2                              True                   False
# 3                              True                   False
# 4                             False                   False
# ...                             ...                     ...
# 48836                          True                   False
# 48837                          True                   False
# 48839                          True                   False
# 48840                          True                   False
# 48841                          True                   False
#
#        native-country_Yugoslavia
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 48836                      False
# 48837                      False
# 48839                      False
# 48840                      False
# 48841                      False
#
# [47621 rows x 418 columns]

# %%
y = labelencoder.fit_transform(y)
y = pd.DataFrame(y, columns=['income'])
y
# Out:
#        income
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 47616       0
# 47617       0
# 47618       0
# 47619       0
# 47620       1
#
# [47621 rows x 1 columns]

# %%
# And finally we'll split the dataset in train and test to create our model

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=0)

# %%
# The first model that we'll create is a neural network, called Multi-layer Perceptron Classifier, with the library scikit-learn
# We'll split it in 3 hidden layers with number of atributes + classe / 2 neurons in the first layer and the half in the second
# Activation function 'relu' (default)
# Batch size of auto (Size of minibatches for stochastic optimizers)
# Learning rate 'adaptive' (keeps the learning rate constant to ‘learning_rate_init’ as long as training loss keeps decreasing)
# Momentum of 0.9 (default)
# Early stopping disabled
# Maximum of 100 iterations
# Random state of None (deafult)

model1 = MLPClassifier(
    verbose=True,
    hidden_layer_sizes=(48,24,48),
    activation='relu',
    batch_size='auto',
    learning_rate='adaptive',
    momentum=0.9,
    early_stopping=False,
    max_iter=500,
    random_state=None
)

model1.fit(X_train, y_train)
# Out:
# c:\Users\hsapa\Box Sync\Henrique\EIA\EIA - VSCode\tensorflow\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1119: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Iteration 1, loss = 0.57599452
# Iteration 2, loss = 0.44033045
# Iteration 3, loss = 0.41852484
# Iteration 4, loss = 0.40212364
# Iteration 5, loss = 0.38880146
# Iteration 6, loss = 0.37744600
# Iteration 7, loss = 0.36952198
# Iteration 8, loss = 0.36713711
# Iteration 9, loss = 0.36156653
# Iteration 10, loss = 0.36298872
# Iteration 11, loss = 0.35915563
# Iteration 12, loss = 0.35723544
# Iteration 13, loss = 0.35536299
# Iteration 14, loss = 0.35463433
# Iteration 15, loss = 0.35400908
# Iteration 16, loss = 0.35092437
# Iteration 17, loss = 0.35101226
# Iteration 18, loss = 0.34979025
# Iteration 19, loss = 0.34949673
# Iteration 20, loss = 0.34757421
# Iteration 21, loss = 0.34578440
# Iteration 22, loss = 0.34612202
# Iteration 23, loss = 0.34468542
# Iteration 24, loss = 0.34391193
# Iteration 25, loss = 0.34435689
# Iteration 26, loss = 0.34354234
# Iteration 27, loss = 0.34115417
# Iteration 28, loss = 0.34099187
# Iteration 29, loss = 0.34288703
# Iteration 30, loss = 0.33895924
# Iteration 31, loss = 0.33981314
# Iteration 32, loss = 0.34005031
# Iteration 33, loss = 0.33913117
# Iteration 34, loss = 0.33695239
# Iteration 35, loss = 0.33628653
# Iteration 36, loss = 0.33715643
# Iteration 37, loss = 0.33543222
# Iteration 38, loss = 0.33426286
# Iteration 39, loss = 0.33497792
# Iteration 40, loss = 0.33523499
# Iteration 41, loss = 0.33401230
# Iteration 42, loss = 0.33365586
# Iteration 43, loss = 0.33207523
# Iteration 44, loss = 0.33279918
# Iteration 45, loss = 0.33024322
# Iteration 46, loss = 0.33062549
# Iteration 47, loss = 0.32915203
# Iteration 48, loss = 0.32865063
# Iteration 49, loss = 0.32782829
# Iteration 50, loss = 0.32699719
# Iteration 51, loss = 0.32747126
# Iteration 52, loss = 0.32670703
# Iteration 53, loss = 0.32661399
# Iteration 54, loss = 0.32704572
# Iteration 55, loss = 0.32551072
# Iteration 56, loss = 0.32668127
# Iteration 57, loss = 0.32450941
# Iteration 58, loss = 0.32368587
# Iteration 59, loss = 0.32409607
# Iteration 60, loss = 0.32290900
# Iteration 61, loss = 0.32247581
# Iteration 62, loss = 0.32122742
# Iteration 63, loss = 0.32257540
# Iteration 64, loss = 0.32154872
# Iteration 65, loss = 0.32094585
# Iteration 66, loss = 0.32094029
# Iteration 67, loss = 0.32237498
# Iteration 68, loss = 0.32053804
# Iteration 69, loss = 0.32013998
# Iteration 70, loss = 0.31906740
# Iteration 71, loss = 0.31902865
# Iteration 72, loss = 0.31836999
# Iteration 73, loss = 0.31840363
# Iteration 74, loss = 0.31783258
# Iteration 75, loss = 0.31788980
# Iteration 76, loss = 0.31708917
# Iteration 77, loss = 0.31781500
# Iteration 78, loss = 0.31901944
# Iteration 79, loss = 0.31732181
# Iteration 80, loss = 0.31715190
# Iteration 81, loss = 0.31748407
# Iteration 82, loss = 0.31920116
# Iteration 83, loss = 0.31702688
# Iteration 84, loss = 0.31518610
# Iteration 85, loss = 0.31466783
# Iteration 86, loss = 0.31542409
# Iteration 87, loss = 0.31449678
# Iteration 88, loss = 0.31494863
# Iteration 89, loss = 0.31409650
# Iteration 90, loss = 0.31527831
# Iteration 91, loss = 0.31436055
# Iteration 92, loss = 0.31379043
# Iteration 93, loss = 0.31289301
# Iteration 94, loss = 0.31290914
# Iteration 95, loss = 0.31265460
# Iteration 96, loss = 0.31174776
# Iteration 97, loss = 0.31177509
# Iteration 98, loss = 0.31134886
# Iteration 99, loss = 0.31184551
# Iteration 100, loss = 0.31166085
# Iteration 101, loss = 0.31208214
# Iteration 102, loss = 0.31266178
# Iteration 103, loss = 0.31109232
# Iteration 104, loss = 0.30992663
# Iteration 105, loss = 0.30923998
# Iteration 106, loss = 0.30961932
# Iteration 107, loss = 0.31096667
# Iteration 108, loss = 0.30921050
# Iteration 109, loss = 0.31054842
# Iteration 110, loss = 0.30965942
# Iteration 111, loss = 0.31033179
# Iteration 112, loss = 0.30877703
# Iteration 113, loss = 0.30874377
# Iteration 114, loss = 0.30762907
# Iteration 115, loss = 0.30950947
# Iteration 116, loss = 0.30829602
# Iteration 117, loss = 0.30737665
# Iteration 118, loss = 0.30841676
# Iteration 119, loss = 0.30752075
# Iteration 120, loss = 0.30751735
# Iteration 121, loss = 0.30696359
# Iteration 122, loss = 0.30718027
# Iteration 123, loss = 0.30751335
# Iteration 124, loss = 0.30701876
# Iteration 125, loss = 0.30621128
# Iteration 126, loss = 0.30522622
# Iteration 127, loss = 0.30701429
# Iteration 128, loss = 0.30570351
# Iteration 129, loss = 0.30593338
# Iteration 130, loss = 0.30521106
# Iteration 131, loss = 0.30480204
# Iteration 132, loss = 0.30744425
# Iteration 133, loss = 0.30586937
# Iteration 134, loss = 0.30387990
# Iteration 135, loss = 0.30552629
# Iteration 136, loss = 0.30435114
# Iteration 137, loss = 0.30457004
# Iteration 138, loss = 0.30445241
# Iteration 139, loss = 0.30416542
# Iteration 140, loss = 0.30432691
# Iteration 141, loss = 0.30513607
# Iteration 142, loss = 0.30311193
# Iteration 143, loss = 0.30350947
# Iteration 144, loss = 0.30397642
# Iteration 145, loss = 0.30355256
# Iteration 146, loss = 0.30317978
# Iteration 147, loss = 0.30413672
# Iteration 148, loss = 0.30293479
# Iteration 149, loss = 0.30373104
# Iteration 150, loss = 0.30145781
# Iteration 151, loss = 0.30429654
# Iteration 152, loss = 0.30222999
# Iteration 153, loss = 0.30312291
# Iteration 154, loss = 0.30206002
# Iteration 155, loss = 0.30251932
# Iteration 156, loss = 0.30097025
# Iteration 157, loss = 0.30222876
# Iteration 158, loss = 0.30234334
# Iteration 159, loss = 0.30106596
# Iteration 160, loss = 0.30138034
# Iteration 161, loss = 0.30143452
# Iteration 162, loss = 0.30174481
# Iteration 163, loss = 0.30105291
# Iteration 164, loss = 0.30293962
# Iteration 165, loss = 0.30143819
# Iteration 166, loss = 0.30035475
# Iteration 167, loss = 0.30067151
# Iteration 168, loss = 0.30241281
# Iteration 169, loss = 0.29986088
# Iteration 170, loss = 0.29992054
# Iteration 171, loss = 0.30093301
# Iteration 172, loss = 0.29907693
# Iteration 173, loss = 0.29967505
# Iteration 174, loss = 0.29902367
# Iteration 175, loss = 0.29968306
# Iteration 176, loss = 0.29824091
# Iteration 177, loss = 0.29873930
# Iteration 178, loss = 0.30051878
# Iteration 179, loss = 0.29934043
# Iteration 180, loss = 0.29850910
# Iteration 181, loss = 0.29874544
# Iteration 182, loss = 0.30021639
# Iteration 183, loss = 0.30025028
# Iteration 184, loss = 0.29787894
# Iteration 185, loss = 0.29811359
# Iteration 186, loss = 0.29901858
# Iteration 187, loss = 0.29936501
# Iteration 188, loss = 0.29932738
# Iteration 189, loss = 0.29757321
# Iteration 190, loss = 0.29864946
# Iteration 191, loss = 0.29769942
# Iteration 192, loss = 0.29801973
# Iteration 193, loss = 0.29818189
# Iteration 194, loss = 0.29821224
# Iteration 195, loss = 0.29863302
# Iteration 196, loss = 0.29643099
# Iteration 197, loss = 0.29755896
# Iteration 198, loss = 0.29965116
# Iteration 199, loss = 0.29716022
# Iteration 200, loss = 0.29701897
# Iteration 201, loss = 0.29760739
# Iteration 202, loss = 0.29642889
# Iteration 203, loss = 0.29610817
# Iteration 204, loss = 0.29672031
# Iteration 205, loss = 0.29649154
# Iteration 206, loss = 0.29580263
# Iteration 207, loss = 0.29610081
# Iteration 208, loss = 0.29568968
# Iteration 209, loss = 0.29644102
# Iteration 210, loss = 0.29598212
# Iteration 211, loss = 0.29580427
# Iteration 212, loss = 0.29565673
# Iteration 213, loss = 0.29560397
# Iteration 214, loss = 0.29473468
# Iteration 215, loss = 0.29522311
# Iteration 216, loss = 0.29355994
# Iteration 217, loss = 0.29600555
# Iteration 218, loss = 0.29636811
# Iteration 219, loss = 0.29472428
# Iteration 220, loss = 0.29397587
# Iteration 221, loss = 0.29358699
# Iteration 222, loss = 0.29357191
# Iteration 223, loss = 0.29515777
# Iteration 224, loss = 0.29585930
# Iteration 225, loss = 0.29373061
# Iteration 226, loss = 0.29277637
# Iteration 227, loss = 0.29327883
# Iteration 228, loss = 0.29401561
# Iteration 229, loss = 0.29413930
# Iteration 230, loss = 0.29300533
# Iteration 231, loss = 0.29286579
# Iteration 232, loss = 0.29385913
# Iteration 233, loss = 0.29276254
# Iteration 234, loss = 0.29264433
# Iteration 235, loss = 0.29321946
# Iteration 236, loss = 0.29457444
# Iteration 237, loss = 0.29355661
# Iteration 238, loss = 0.29176602
# Iteration 239, loss = 0.29265205
# Iteration 240, loss = 0.29281522
# Iteration 241, loss = 0.29294730
# Iteration 242, loss = 0.29194553
# Iteration 243, loss = 0.29271448
# Iteration 244, loss = 0.29194233
# Iteration 245, loss = 0.29167570
# Iteration 246, loss = 0.29114984
# Iteration 247, loss = 0.29268235
# Iteration 248, loss = 0.29115074
# Iteration 249, loss = 0.29235962
# Iteration 250, loss = 0.29478246
# Iteration 251, loss = 0.29203253
# Iteration 252, loss = 0.29078679
# Iteration 253, loss = 0.29102515
# Iteration 254, loss = 0.28949613
# Iteration 255, loss = 0.29158005
# Iteration 256, loss = 0.29120439
# Iteration 257, loss = 0.29131079
# Iteration 258, loss = 0.29051562
# Iteration 259, loss = 0.29343808
# Iteration 260, loss = 0.29290843
# Iteration 261, loss = 0.29181469
# Iteration 262, loss = 0.29167168
# Iteration 263, loss = 0.28864326
# Iteration 264, loss = 0.29130496
# Iteration 265, loss = 0.29060202
# Iteration 266, loss = 0.28859190
# Iteration 267, loss = 0.29022123
# Iteration 268, loss = 0.28840422
# Iteration 269, loss = 0.29114184
# Iteration 270, loss = 0.29042513
# Iteration 271, loss = 0.28916500
# Iteration 272, loss = 0.28842130
# Iteration 273, loss = 0.29096434
# Iteration 274, loss = 0.29115458
# Iteration 275, loss = 0.28987948
# Iteration 276, loss = 0.28912907
# Iteration 277, loss = 0.28941717
# Iteration 278, loss = 0.28940433
# Iteration 279, loss = 0.28918760
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(hidden_layer_sizes=(48, 24, 48), learning_rate='adaptive',
#               max_iter=500, verbose=True)

# %%
# We'll create a visual graph to see the loss curve of the model

plt.plot(model1.loss_curve_)
plt.xlabel("Interections")
plt.ylabel("Loss_Value")
plt.title("Loss")
plt.show()

# %%
# Now we'll predict the test dataset

prevision = model1.predict(X_test)
prevision
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# We'll predict the test dataset and check the accuracy, precision, recall and f1-score

accuracy = accuracy_score(y_test, prevision)
precision = precision_score(y_test, prevision, average='weighted')
recall = recall_score(y_test, prevision, average='weighted')
f1 = f1_score(y_test, prevision, average='weighted')
print(f'Accuracy: {accuracy}, Precision: {precision}, Recall {recall}, F1: {f1}')
# Out:
# Accuracy: 0.8444040036396724, Precision: 0.83633962108579, Recall 0.8444040036396724, F1: 0.8368257936152347

# %%
# In this second model we'll create a neural network with the library tensorflow, in which we must define each layer and the activation function

model2 = Sequential()
model2.add(Dense(units=48, activation='relu', input_dim=X_train.shape[1]))
model2.add(Dropout(0.2))
model2.add(Dense(units=24, activation='relu'))
model2.add(Dropout(0.2))
model2.add(Dense(units=48, activation='relu'))
model2.add(Dropout(0.2))
model2.add(Dense(units=1, activation='sigmoid'))
# Out:
# c:\Users\hsapa\Box Sync\Henrique\EIA\EIA - VSCode\tensorflow\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model2.fit(X_train, y_train, epochs=50, batch_size=50)
# Out:
# Epoch 1/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7301 - loss: 0.5881
# Epoch 2/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7806 - loss: 0.4518
# Epoch 3/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8064 - loss: 0.4070
# Epoch 4/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8065 - loss: 0.3910
# Epoch 5/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8099 - loss: 0.3800
# Epoch 6/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8119 - loss: 0.3756
# Epoch 7/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8139 - loss: 0.3732
# Epoch 8/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8140 - loss: 0.3724
# Epoch 9/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8171 - loss: 0.3693
# Epoch 10/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8185 - loss: 0.3684
# Epoch 11/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8195 - loss: 0.3630
# Epoch 12/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8234 - loss: 0.3618
# Epoch 13/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8178 - loss: 0.3702
# Epoch 14/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8183 - loss: 0.3605
# Epoch 15/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8183 - loss: 0.3698
# Epoch 16/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8226 - loss: 0.3620
# Epoch 17/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8189 - loss: 0.3655
# Epoch 18/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8227 - loss: 0.3589
# Epoch 19/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8210 - loss: 0.3614
# Epoch 20/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8218 - loss: 0.3592
# Epoch 21/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8226 - loss: 0.3604
# Epoch 22/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8193 - loss: 0.3602
# Epoch 23/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8217 - loss: 0.3566
# Epoch 24/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8199 - loss: 0.3587
# Epoch 25/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8208 - loss: 0.3572
# Epoch 26/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8209 - loss: 0.3611
# Epoch 27/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8183 - loss: 0.3631
# Epoch 28/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8193 - loss: 0.3613
# Epoch 29/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8179 - loss: 0.3570
# Epoch 30/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8183 - loss: 0.3609
# Epoch 31/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8241 - loss: 0.3542
# Epoch 32/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8225 - loss: 0.3524
# Epoch 33/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8224 - loss: 0.3573
# Epoch 34/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8202 - loss: 0.3627
# Epoch 35/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8249 - loss: 0.3552
# Epoch 36/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8264 - loss: 0.3543
# Epoch 37/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8204 - loss: 0.3568
# Epoch 38/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8217 - loss: 0.3576
# Epoch 39/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8225 - loss: 0.3595
# Epoch 40/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8205 - loss: 0.3560
# Epoch 41/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8259 - loss: 0.3513
# Epoch 42/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8246 - loss: 0.3562
# Epoch 43/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8230 - loss: 0.3548
# Epoch 44/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8219 - loss: 0.3546
# Epoch 45/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8210 - loss: 0.3571
# Epoch 46/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8225 - loss: 0.3575
# Epoch 47/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8236 - loss: 0.3517
# Epoch 48/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8214 - loss: 0.3552
# Epoch 49/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8215 - loss: 0.3545
# Epoch 50/50
# 667/667 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8182 - loss: 0.3566

# %%
# As we used the activation function 'sigmoid' in the last layer, the output will be a value between 0 and 1
# and we must convert it to 0 or 1, so we'll use the function 'astype' to do this

prevision2 = model2.predict(X_test)

y_pred = (prevision2 > 0.5).astype('int32')
y_pred
# Out:
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=int32)

# %%
accuracy_2 = accuracy_score(y_test, y_pred)
precision_2 = precision_score(y_test, y_pred, average='weighted')
recall_2 = recall_score(y_test, y_pred, average='weighted')
f1_2 = f1_score(y_test, y_pred, average='weighted')
print(f'Accuracy: {accuracy_2}, Precision: {precision_2}, Recall {recall_2}, F1: {f1_2}')
# Out:
# Accuracy: 0.8301952824245817, Precision: 0.8210227412923632, Recall 0.8301952824245817, F1: 0.8229099930737332

# %%
# In this third model we'll use the TPOT library, that will create a model automatically, using genetic algorithms

tpot = TPOTClassifier(
    generations=10,
    population_size=100,
    offspring_size=100,
    mutation_rate=0.9,
    crossover_rate=0.1,
    scoring='accuracy',
    max_time_mins=5,
    random_state=0,
    early_stop=True,
    verbosity=2,
    config_dict='TPOT light'
)
tpot.fit(X_train, y_train)
print("Melhor Modelo: ", tpot.fitted_pipeline_)
# Out:
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# c:\Users\hsapa\Box Sync\Henrique\EIA\EIA - VSCode\tensorflow\Lib\site-packages\sklearn\base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# c:\Users\hsapa\Box Sync\Henrique\EIA\EIA - VSCode\tensorflow\Lib\site-packages\sklearn\base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_classifier
# is_classifier
# is_classifier
# is_classifier
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_classifier
# is_regressor
# c:\Users\hsapa\Box Sync\Henrique\EIA\EIA - VSCode\tensorflow\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#
# 7.01 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: DecisionTreeClassifier(input_matrix, criterion=entropy, max_depth=9, min_samples_leaf=19, min_samples_split=18)
# Melhor Modelo:  Pipeline(steps=[('decisiontreeclassifier',
#                  DecisionTreeClassifier(criterion='entropy', max_depth=9,
#                                         min_samples_leaf=19,
#                                         min_samples_split=18,
#                                         random_state=0))])

# %%
prevision3 = tpot.predict(X_test)

accuracy_3 = accuracy_score(y_test, prevision3)
precision_3 = precision_score(y_test, prevision3, average='weighted')
recall_3 = recall_score(y_test, prevision3, average='weighted')
f1_3 = f1_score(y_test, prevision3, average='weighted')
print(f'Accuracy: {accuracy_3}, Precision: {precision_3}, Recall {recall_3}, F1: {f1_3}')
# Out:
# Accuracy: 0.8553930146286834, Precision: 0.8497857051104291, Recall 0.8553930146286834, F1: 0.8442842485048763

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree

# %%
# In this fourth model we'll use the K-Nearest Neighbors algorithm, as it was considered the best model in the TPOT library

tree = DecisionTreeClassifier(max_depth=10, min_samples_leaf=16,min_samples_split=15,random_state=0)
model4 = tree.fit(X_train,y_train)
model4
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=16, min_samples_split=15,
#                        random_state=0)

# %%
prevision4 = model4.predict(X_test)

accuracy_4 = accuracy_score(y_test, prevision4)
precision_4 = precision_score(y_test, prevision4, average='weighted')
recall_4 = recall_score(y_test, prevision4, average='weighted')
f1_4 = f1_score(y_test, prevision4, average='weighted')
print(f'Accuracy: {accuracy_4}, Precision: {precision_4}, Recall {recall_4}, F1: {f1_4}')
# Out:
# Accuracy: 0.8535731784139428, Precision: 0.8466579820060273, Recall 0.8535731784139428, F1: 0.8445880388301764

# %%
plt.figure(figsize=(20,10))
plot_tree(model4, filled=True, feature_names=X.columns, class_names=True, rounded=True)
plt.show()

# %%
print(f'Accuracy: {accuracy}, Precision: {precision}, Recall {recall}, F1: {f1}')
print(f'Accuracy: {accuracy_2}, Precision: {precision_2}, Recall {recall_2}, F1: {f1_2}')
print(f'Accuracy: {accuracy_3}, Precision: {precision_3}, Recall {recall_3}, F1: {f1_3}')
print(f'Accuracy: {accuracy_4}, Precision: {precision_4}, Recall {recall_4}, F1: {f1_4}')
# Out:
# Accuracy: 0.8444040036396724, Precision: 0.83633962108579, Recall 0.8444040036396724, F1: 0.8368257936152347
# Accuracy: 0.8301952824245817, Precision: 0.8210227412923632, Recall 0.8301952824245817, F1: 0.8229099930737332
# Accuracy: 0.8553930146286834, Precision: 0.8497857051104291, Recall 0.8553930146286834, F1: 0.8442842485048763
# Accuracy: 0.8535731784139428, Precision: 0.8466579820060273, Recall 0.8535731784139428, F1: 0.8445880388301764
